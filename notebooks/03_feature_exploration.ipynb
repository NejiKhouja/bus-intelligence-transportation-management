# %% [markdown]
# # 03 — Feature Exploration
# Exploratory look at demand aggregation and GPS-segment travel times, ahead of any modeling. See `docs/roadmap.md` for what's next.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
from src.data import extraction, transformations
from src.features import demand_features, travel_time_features

# %%
tickets = extraction.extract_archived_tickets(2025)
demand = transformations.aggregate_demand(tickets, freq='D')
demand = demand_features.add_calendar_features(demand)
demand.sort_values('passenger_count', ascending=False).head(10)

# %%
gps = extraction.extract_archived_gps_day('20260601')
segments = transformations.build_gps_segments(gps)
segments = travel_time_features.add_time_of_day_features(segments)
segments['avg_speed_kmh'].describe()
