# %% [markdown]
# # 01 — Database Exploration
# Read-only exploration of the MongoDB instance backing this project. Uses `src/database/explorer.py` and `scripts/explore_database.py` so this notebook and the CLI tool stay consistent.
#
# See `docs/database.md` for the write-up of what was found.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
from src.database import explorer
from src.database.mongo_client import get_db, ping
ping()

# %%
explorer.list_databases()

# %%
db = get_db('winicari')
stats = sorted((explorer.collection_stats(db, c) for c in explorer.list_collections(db)),
               key=lambda r: r['estimated_count'], reverse=True)
stats[:15]

# %%
explorer.sample_documents(db, 'ligne', 2)

# %%
explorer.daily_collections_span(get_db('Historique_pos'))

# %%
explorer.timestamp_range(db, 'position', 'date')
